# %%
import pandas as pd
import plotly_express as px

df = pd.read_csv('european_wholesale_electricity_price_data_daily-4.csv') # copy data downloaded from https://ember-climate.org/data/data-catalogue/ to 'df' DataFrame
df
# Out:
#        Country ISO3 Code        Date  Price (EUR/MWhe)
# 0      Austria       AUT  2015-01-01             35.86
# 1      Austria       AUT  2015-01-02             35.86
# 2      Austria       AUT  2015-01-03             35.86
# 3      Austria       AUT  2015-01-04             35.86
# 4      Austria       AUT  2015-01-05             36.18
# ...        ...       ...         ...               ...
# 78387   Sweden       SWE  2022-11-26            218.72
# 78388   Sweden       SWE  2022-11-27            133.71
# 78389   Sweden       SWE  2022-11-28            191.90
# 78390   Sweden       SWE  2022-11-29            357.70
# 78391   Sweden       SWE  2022-11-30            390.77
#
# [78392 rows x 4 columns]

# %%
country_names  = df['Country'].unique() # assign unique country names to country_names numpy array
country_codes = df['ISO3 Code'].unique() # assign unique ISO3 country codes to country_codes numpy array
countries_dict = {country_names[i]: country_codes[i] for i in range(len(country_names))} # merge country names and country ISO codes into 'countries_dict' dictionary

df_temp = df.pivot(index='Date', columns='Country', values='Price (EUR/MWhe)') # move country names to columns
df_temp = df_temp.groupby(pd.PeriodIndex(df_temp.index, freq="M")).mean() # calculate monthly average values per country

# %%
df =  df[df['Country'] == 'Germany'] # show only data for Germany
fig = px.line(df, 
    x=df['Date'],
    y=df['Price (EUR/MWhe)'],
    color=df['Country'],
    height=500, 
    width=900,
    template='plotly_dark'
    )  # charts the data
fig.show() # chart daily the data

# # create map chart
# map_fig = px.scatter_geo(df,
#                         locations='iso_alpha',
#                         projection='orthographic',
#                         color='continent',
#                         opacity=0.8,
#                         hover_name='country',
#                         hover_data=['lifeExp', 'pop', 'year']
# )
# map_fig.show()

# %%
df_monthly_avg = df.groupby(pd.PeriodIndex(df['Date'], freq="M"))['Price (EUR/MWhe)'].mean() # derive monthly average based on daily values 
df_monthly_avg
# fig = px.line(df_monthly_avg, 
#     x=df_monthly_avg['Date'],
#     y=df_monthly_avg['Price (EUR/MWhe)'],
#     color=df_monthly_avg['Country'],
#     height=500, 
#     width=900,
#     template='plotly_dark'
#     )  # charts the data
# fig.show() # chart the monthly data
# Out:
# pandas.core.series.Series
